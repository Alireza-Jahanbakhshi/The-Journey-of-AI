# %%
# Import the necessary packages
import numpy as np

class Perceptron:
  '''
    N: The number of columns in the input feature vectors 
    alpha: Learning Rate
  '''
  def __init__(self, N, alpha=0.1):
    # Initialize te weight matrix and store the learning rate
    self.W = np.random.randn(N + 1) / np.sqrt(N)
    self.alpha = alpha

  def step(self, x):
    return 1 if x > 0 else 0

  def fit (self, X, y, epochs=10):
    '''
      X: Training Data
      y: Labels
    '''
    X = np.c_[X, np.ones((X.shape[0]))]
    # Loop over the desired number of epochs
    for epoch in np.arange(0, epochs):
      # Loop over each individual data point
      for (x, target) in zip(X, y):
        # Take the dot product between the input features
        # and te weight matrix, then pass this value
        # through te step function to obtain the prediction
        p = self.step(np.dot(x, self.W))
        # Only perform a weight update if our prediction
        # does not match the target
        if p != target:
          # Determine the error
          error = p - target
          # Update the weight matrix
          self.W += -self.alpha * error * x

  def predict(self, X, addBis=True):
    X = np.atleast_2d(X)
    if addBis:
      X = np.c_[X, np.ones((X.shape[0]))]
    return self.step(np.dot(X, self.W))

# %%
# Construct the OR dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [1]])
# Define our perceptron and train int
print("[INFO] training percpteron...")
p = Perceptron(X.shape[1], alpha=0.1)
p.fit(X, y, epochs=20)
# Out:
# [INFO] training percpteron...

# %%
# Now that our preceptron is trained we can evaluate it
print("[INFO] testing percpteron...")
# Now our network is trained, loop over the points
for (x, target) in zip(X, y):
  pred = p.predict(x)
  print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] testing percpteron...
# [INFO] data=[0 0], ground-truth=0, pred=0
# [INFO] data=[0 1], ground-truth=1, pred=1
# [INFO] data=[1 0], ground-truth=1, pred=1
# [INFO] data=[1 1], ground-truth=1, pred=1

# %%
# Construct the AND dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [1]])
# Define our perceptron and train int
print("[INFO] training percpteron...")
p = Perceptron(X.shape[1], alpha=0.1)
p.fit(X, y, epochs=20)
# Now that our preceptron is trained we can evaluate it
print("[INFO] testing percpteron...")
# Now our network is trained, loop over the points
for (x, target) in zip(X, y):
  pred = p.predict(x)
  print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] training percpteron...
# [INFO] testing percpteron...
# [INFO] data=[0 0], ground-truth=0, pred=0
# [INFO] data=[0 1], ground-truth=0, pred=0
# [INFO] data=[1 0], ground-truth=0, pred=0
# [INFO] data=[1 1], ground-truth=1, pred=1

# %%
# Construct the XOR dataset ---> Need to multilayer perceptron(MLP) or feed forward neural network
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])
# Define our perceptron and train int
print("[INFO] training percpteron...")
p = Perceptron(X.shape[1], alpha=0.1)
p.fit(X, y, epochs=20)
# Now that our preceptron is trained we can evaluate it
print("[INFO] testing percpteron...")
# Now our network is trained, loop over the points
for (x, target) in zip(X, y):
  pred = p.predict(x)
  print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] training percpteron...
# [INFO] testing percpteron...
# [INFO] data=[0 0], ground-truth=0, pred=1
# [INFO] data=[0 1], ground-truth=1, pred=1
# [INFO] data=[1 0], ground-truth=1, pred=0
# [INFO] data=[1 1], ground-truth=0, pred=0

# %%
#Activation Functions
import numpy as np
import matplotlib.pyplot as plt

# Sigmoid Activation Function
def sigmoid(x):
    return 1/(1+np.exp(-x))

# Derivative of Sigmoid
def der_sigmoid(x):
    return sigmoid(x) * (1- sigmoid(x))

# Generating data to plot
x_data = np.linspace(-10,10,100)
y_data = sigmoid(x_data)
dy_data = der_sigmoid(x_data)

# Plotting
plt.plot(x_data, y_data, x_data, dy_data)
plt.title('Sigmoid Activation Function & Derivative')
plt.legend(['sigmoid','der_sigmoid'])
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hyperbolic Tangent (htan) Activation Function
def htan(x):
    return (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))

# htan derivative
def der_htan(x):
    return 1 - htan(x) * htan(x)

# Generating data for Graph
x_data = np.linspace(-6,6,100)
y_data = htan(x_data)
dy_data = der_htan(x_data)

# Graph
plt.plot(x_data, y_data, x_data, dy_data)
plt.title('htan Activation Function & Derivative')
plt.legend(['htan','der_htan'])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rectified Linear Unit (ReLU)
def ReLU(x):
    data = [max(0,value) for value in x]
    return np.array(data, dtype=float)

# Derivative for ReLU
def der_ReLU(x):
    data = [1 if value>0 else 0 for value in x]
    return np.array(data, dtype=float)

# Generating data for Graph
x_data = np.linspace(-10,10,100)
y_data = ReLU(x_data)
dy_data = der_ReLU(x_data)

# Graph
plt.plot(x_data, y_data, x_data, dy_data)
plt.title('ReLU Activation Function & Derivative')
plt.legend(['ReLU','der_ReLU'])
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Softmax Activation Function
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=0)

# Generating data to plot
x_data = np.linspace(-10,10,100)
y_data = softmax(x_data)

# Plotting
plt.plot(x_data, y_data)
plt.title('Softmax Activation Function')
plt.legend(['softmax'])
plt.grid()
plt.show()

# %%
#LossFunctions
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from itertools import product

# %%
def func(x):
    return x**2 - 2*x - 3

def fprime(x):
    return 2*x - 2

# %%
def plotFunc(x0):
    x = np.linspace(-5, 7, 100)
    plt.plot(x, func(x))
    plt.plot(x0, func(x0), 'ko')
    plt.xlabel('$x$')
    plt.ylabel('$f(x)$')
    plt.title('0bjective Function')
    
def plotPath(xs, ys, x0):
    plotFunc(x0)
    plt.plot(xs, ys, linestyle='--', marker='o', color='#F12F79')
    plt.plot(xs[-1], ys[-1], 'ko')

# %%
x0=-4
plotFunc(x0)

# %%
def GradientDescentSimple(func, fprime, x0, alpha, tol=1e-5, max_iter=1000):
    # initialize x, fo), and -f'(x)
    xk = x0
    fk = func(xk)
    pk = ~fprime(xk)
    # initialize number of steps, save x and f(x)
    num_iter = 0
    curve_x = [xk]
    curve_y = [fk]
    # take steps
    while abs(pk) > tol and num_iter < max_iter:
        # calculate new x, f(x), and -f'(x)
        xk = xk + alpha * pk
        fk = func(xk)
        pk = -fprime(xk)
        # increase number of steps by 1, save new x and f(x)
        num_iter += 1
        curve_x.append(xk)
        curve_y.append(fk)
    # print results
    if num_iter == max_iter:
        print('Gradient descent does not converge.')
    else:
        print('Solution found:\n y = {:.4f}\n x = {:.4f}'.format(fk, xk))
    return curve_x, curve_y

# %%
xs, ys = GradientDescentSimple(func, fprime, x0, alpha=0.1)
plotPath(xs, ys, x0)
# Out:
# Solution found:
#  y = -4.0000
#  x = 1.0000

# %%
xs, ys = GradientDescentSimple(func, fprime, x0, alpha=0.9)
plotPath(xs, ys, x0)
# Out:
# Solution found:
#  y = -4.0000
#  x = 1.0000

# %%
xs, ys = GradientDescentSimple(func, fprime, x0, alpha=1.01, max_iter=8)
plotPath(xs, ys, x0)
# Out:
# Gradient descent does not converge.

# %%
#Keras
import pandas as pd

# %%
df = pd.read_csv('housepricedata.csv')

# %%
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
X = dataset[:,0:10]

# %%
Y = dataset[:,10]

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.29.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pa\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#https://www.kaggle.com/general/274656
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
Dense(32, activation='relu', input_shape=(10,)),
Dense(32, activation='relu'),
Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
loss='binary_crossentropy',
metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
batch_size=32, epochs=100,
validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 12ms/step - loss: 0.6969 - accuracy: 0.5020 - val_loss: 0.6866 - val_accuracy: 0.5799
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.5920 - val_loss: 0.6809 - val_accuracy: 0.6027
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.6526 - val_loss: 0.6765 - val_accuracy: 0.7078
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6750 - accuracy: 0.6947 - val_loss: 0.6723 - val_accuracy: 0.7123
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6698 - accuracy: 0.6986 - val_loss: 0.6681 - val_accuracy: 0.6941
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.6937 - val_loss: 0.6633 - val_accuracy: 0.7032
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6577 - accuracy: 0.7123 - val_loss: 0.6569 - val_accuracy: 0.7215
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6502 - accuracy: 0.7446 - val_loss: 0.6504 - val_accuracy: 0.7443
# Epoch 9/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6430 - accuracy: 0.7652 - val_loss: 0.6445 - val_accuracy: 0.7489
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6362 - accuracy: 0.7798 - val_loss: 0.6387 - val_accuracy: 0.7534
# Epoch 11/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6289 - accuracy: 0.7828 - val_loss: 0.6325 - val_accuracy: 0.7534
# Epoch 12/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6213 - accuracy: 0.7886 - val_loss: 0.6258 - val_accuracy: 0.7580
# Epoch 13/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.7994 - val_loss: 0.6188 - val_accuracy: 0.7534
# Epoch 14/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6047 - accuracy: 0.8200 - val_loss: 0.6121 - val_accuracy: 0.7397
# Epoch 15/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5958 - accuracy: 0.8102 - val_loss: 0.6043 - val_accuracy: 0.7717
# Epoch 16/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5863 - accuracy: 0.8190 - val_loss: 0.5962 - val_accuracy: 0.7763
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5767 - accuracy: 0.8278 - val_loss: 0.5878 - val_accuracy: 0.7808
# Epoch 18/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5663 - accuracy: 0.8346 - val_loss: 0.5791 - val_accuracy: 0.7900
# Epoch 19/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5559 - accuracy: 0.8474 - val_loss: 0.5705 - val_accuracy: 0.7900
# Epoch 20/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5455 - accuracy: 0.8474 - val_loss: 0.5614 - val_accuracy: 0.7945
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5346 - accuracy: 0.8493 - val_loss: 0.5521 - val_accuracy: 0.8037
# Epoch 22/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5237 - accuracy: 0.8611 - val_loss: 0.5434 - val_accuracy: 0.8037
# Epoch 23/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5128 - accuracy: 0.8601 - val_loss: 0.5338 - val_accuracy: 0.8174
# Epoch 24/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.8718 - val_loss: 0.5251 - val_accuracy: 0.8128
# Epoch 25/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.
# Epoch 67/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2886 - accuracy: 0.8894 - val_loss: 0.3544 - val_accuracy: 0.8447
# Epoch 68/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2870 - accuracy: 0.8904 - val_loss: 0.3525 - val_accuracy: 0.8447
# Epoch 69/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2860 - accuracy: 0.8894 - val_loss: 0.3540 - val_accuracy: 0.8447
# Epoch 70/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2850 - accuracy: 0.8894 - val_loss: 0.3526 - val_accuracy: 0.8447
# Epoch 71/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2836 - accuracy: 0.8914 - val_loss: 0.3499 - val_accuracy: 0.8447
# Epoch 72/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2826 - accuracy: 0.8943 - val_loss: 0.3525 - val_accuracy: 0.8447
# Epoch 73/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2812 - accuracy: 0.8914 - val_loss: 0.3494 - val_accuracy: 0.8447
# Epoch 74/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2800 - accuracy: 0.8973 - val_loss: 0.3489 - val_accuracy: 0.8447
# Epoch 75/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2795 - accuracy: 0.8894 - val_loss: 0.3467 - val_accuracy: 0.8402
# Epoch 76/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.8953 - val_loss: 0.3476 - val_accuracy: 0.8447
# Epoch 77/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 0.8943 - val_loss: 0.3432 - val_accuracy: 0.8447
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2761 - accuracy: 0.8973 - val_loss: 0.3457 - val_accuracy: 0.8493
# Epoch 79/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2749 - accuracy: 0.8953 - val_loss: 0.3408 - val_accuracy: 0.8356
# Epoch 80/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2744 - accuracy: 0.8973 - val_loss: 0.3414 - val_accuracy: 0.8447
# Epoch 81/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2735 - accuracy: 0.8953 - val_loss: 0.3421 - val_accuracy: 0.8447
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2729 - accuracy: 0.8914 - val_loss: 0.3419 - val_accuracy: 0.8447
# Epoch 83/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2713 - accuracy: 0.8943 - val_loss: 0.3391 - val_accuracy: 0.8447
# Epoch 84/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2689 - accuracy: 0.8982 - val_loss: 0.3356 - val_accuracy: 0.8447
# Epoch 85/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2708 - accuracy: 0.8992 - val_loss: 0.3356 - val_accuracy: 0.8402
# Epoch 86/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2702 - accuracy: 0.8973 - val_loss: 0.3363 - val_accuracy: 0.8447
# Epoch 87/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2686 - accuracy: 0.8973 - val_loss: 0.3368 - val_accuracy: 0.8447
# Epoch 88/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2674 - accuracy: 0.8992 - val_loss: 0.3389 - val_accuracy: 0.8447
# Epoch 89/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2668 - accuracy: 0.8982 - val_loss: 0.3363 - val_accuracy: 0.8447
# Epoch 90/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.8992 - val_loss: 0.3391 - val_accuracy: 0.8402
# Epoch 91/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2658 - accuracy: 0.8953 - val_loss: 0.3349 - val_accuracy: 0.8447
# Epoch 92/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.9022 - val_loss: 0.3330 - val_accuracy: 0.8447
# Epoch 93/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2634 - accuracy: 0.8982 - val_loss: 0.3352 - val_accuracy: 0.8493
# Epoch 94/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2634 - accuracy: 0.9022 - val_loss: 0.3329 - val_accuracy: 0.8447
# Epoch 95/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2626 - accuracy: 0.9022 - val_loss: 0.3332 - val_accuracy: 0.8447
# Epoch 96/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2609 - accuracy: 0.9002 - val_loss: 0.3276 - val_accuracy: 0.8493
# Epoch 97/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.8973 - val_loss: 0.3313 - val_accuracy: 0.8447
# Epoch 98/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2607 - accuracy: 0.9051 - val_loss: 0.3270 - val_accuracy: 0.8447
# Epoch 99/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9051 - val_loss: 0.3268 - val_accuracy: 0.8493
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.9022 - val_loss: 0.3281 - val_accuracy: 0.8447

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3065 - accuracy: 0.8676
# 0.8675799369812012

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
model_2 = Sequential([
Dense(1000, activation='relu', input_shape=(10,)),
Dense(1000, activation='relu'),
Dense(1000, activation='relu'),
Dense(1000, activation='relu'),
Dense(1, activation='sigmoid'),
])

model_2.compile(optimizer='adam',
loss='binary_crossentropy',
metrics=['accuracy'])

hist_2 = model_2.fit(X_train, Y_train,
batch_size=32, epochs=100,
validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 3s 53ms/step - loss: 0.4557 - accuracy: 0.7994 - val_loss: 0.4957 - val_accuracy: 0.8174
# Epoch 2/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0
100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1506 - accuracy: 0.9364 - val_loss: 0.4049 - val_accuracy: 0.8584
# Epoch 61/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1279 - accuracy: 0.9511 - val_loss: 0.3931 - val_accuracy: 0.8813
# Epoch 62/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1300 - accuracy: 0.9530 - val_loss: 0.4052 - val_accuracy: 0.8858
# Epoch 63/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1386 - accuracy: 0.9462 - val_loss: 0.3986 - val_accuracy: 0.8539
# Epoch 64/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1388 - accuracy: 0.9491 - val_loss: 0.4229 - val_accuracy: 0.8447
# Epoch 65/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1244 - accuracy: 0.9540 - val_loss: 0.4951 - val_accuracy: 0.8447
# Epoch 66/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.1569 - accuracy: 0.9364 - val_loss: 0.3794 - val_accuracy: 0.8767
# Epoch 67/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1730 - accuracy: 0.9335 - val_loss: 0.3167 - val_accuracy: 0.8813
# Epoch 68/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1486 - accuracy: 0.9393 - val_loss: 0.3257 - val_accuracy: 0.8767
# Epoch 69/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1460 - accuracy: 0.9432 - val_loss: 0.3004 - val_accuracy: 0.8584
# Epoch 70/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1355 - accuracy: 0.9511 - val_loss: 0.4066 - val_accuracy: 0.8447
# Epoch 71/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1345 - accuracy: 0.9472 - val_loss: 0.4254 - val_accuracy: 0.8356
# Epoch 72/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1113 - accuracy: 0.9530 - val_loss: 0.4563 - val_accuracy: 0.8721
# Epoch 73/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1349 - accuracy: 0.9521 - val_loss: 0.3597 - val_accuracy: 0.8721
# Epoch 74/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1367 - accuracy: 0.9432 - val_loss: 0.4792 - val_accuracy: 0.8402
# Epoch 75/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1173 - accuracy: 0.9511 - val_loss: 0.4345 - val_accuracy: 0.8539
# Epoch 76/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1297 - accuracy: 0.9481 - val_loss: 0.4104 - val_accuracy: 0.8767
# Epoch 77/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1438 - accuracy: 0.9481 - val_loss: 0.3920 - val_accuracy: 0.8813
# Epoch 78/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1420 - accuracy: 0.9501 - val_loss: 0.4790 - val_accuracy: 0.8813
# Epoch 79/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1217 - accuracy: 0.9530 - val_loss: 0.5266 - val_accuracy: 0.8676
# Epoch 80/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1249 - accuracy: 0.9501 - val_loss: 0.4184 - val_accuracy: 0.8676
# Epoch 81/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1060 - accuracy: 0.9569 - val_loss: 0.5243 - val_accuracy: 0.8447
# Epoch 82/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1102 - accuracy: 0.9540 - val_loss: 0.4679 - val_accuracy: 0.8630
# Epoch 83/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1028 - accuracy: 0.9618 - val_loss: 0.4294 - val_accuracy: 0.8767
# Epoch 84/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1426 - accuracy: 0.9462 - val_loss: 0.4216 - val_accuracy: 0.8539
# Epoch 85/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1327 - accuracy: 0.9501 - val_loss: 0.5940 - val_accuracy: 0.8356
# Epoch 86/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1298 - accuracy: 0.9442 - val_loss: 0.3999 - val_accuracy: 0.8721
# Epoch 87/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1222 - accuracy: 0.9511 - val_loss: 0.4713 - val_accuracy: 0.8813
# Epoch 88/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1232 - accuracy: 0.9521 - val_loss: 0.5493 - val_accuracy: 0.8721
# Epoch 89/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1157 - accuracy: 0.9550 - val_loss: 0.4694 - val_accuracy: 0.8721
# Epoch 90/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1040 - accuracy: 0.9599 - val_loss: 0.4581 - val_accuracy: 0.8767
# Epoch 91/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1081 - accuracy: 0.9521 - val_loss: 0.5039 - val_accuracy: 0.8402
# Epoch 92/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1373 - accuracy: 0.9481 - val_loss: 0.4737 - val_accuracy: 0.8904
# Epoch 93/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.1447 - accuracy: 0.9511 - val_loss: 0.4695 - val_accuracy: 0.8767
# Epoch 94/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1625 - accuracy: 0.9423 - val_loss: 0.4071 - val_accuracy: 0.8584
# Epoch 95/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1432 - accuracy: 0.9540 - val_loss: 0.3776 - val_accuracy: 0.8584
# Epoch 96/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1185 - accuracy: 0.9521 - val_loss: 0.4391 - val_accuracy: 0.8630
# Epoch 97/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0987 - accuracy: 0.9579 - val_loss: 0.5085 - val_accuracy: 0.8676
# Epoch 98/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0930 - accuracy: 0.9609 - val_loss: 0.5824 - val_accuracy: 0.8676
# Epoch 99/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0960 - accuracy: 0.9589 - val_loss: 0.5379 - val_accuracy: 0.8904
# Epoch 100/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1303 - accuracy: 0.9521 - val_loss: 0.5042 - val_accuracy: 0.8813

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from keras.layers import Dropout

# %%
model_3 = Sequential([
Dense(1000, activation='relu', input_shape=(10,)),
Dropout(0.5),
Dense(1000, activation='relu'),
Dropout(0.5),
Dense(1000, activation='relu'),
Dropout(0.5),
Dense(1000, activation='relu'),
Dropout(0.5),
Dense(1, activation='sigmoid'),
])

# %%
model_3.compile(optimizer='adam',
loss='binary_crossentropy',
metrics=['accuracy'])

hist_3 = model_3.fit(X_train, Y_train,
batch_size=32, epochs=100,
validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 3s 55ms/step - loss: 0.5460 - accuracy: 0.7162 - val_loss: 0.4432 - val_accuracy: 0.8356
# Epoch 2/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.3850 - accuracy: 0.8425 - val_loss: 0.4138 - val_accuracy: 0.7900
# Epoch 3/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3212 - accuracy: 0.8718 - val_loss: 0.3681 - val_accuracy: 0.8356
# Epoch 4/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3385 - accuracy: 0.8669 - val_loss: 0.3546 - val_accuracy: 0.8311
# Epoch 5/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3077 - accuracy: 0.8757 - val_loss: 0.3431 - val_accuracy: 0.8311
# Epoch 6/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2913 - accuracy: 0.8885 - val_loss: 0.3112 - val_accuracy: 0.8539
# Epoch 7/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2737 - accuracy: 0.8933 - val_loss: 0.3542 - val_accuracy: 0.8493
# Epoch 8/100
# 32/32 [==============================] - 3s 97ms/step - loss: 0.2908 - accuracy: 0.8914 - val_loss: 0.3572 - val_accuracy: 0.8219
# Epoch 9/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2885 - accuracy: 0.8963 - val_loss: 0.3265 - val_accuracy: 0.8630
# Epoch 10/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2716 - accuracy: 0.8875 - val_loss: 0.3158 - val_accuracy: 0.8630
# Epoch 11/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.2640 - accuracy: 0.8963 - val_loss: 0.3225 - val_accuracy: 0.8584
# Epoch 12/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.2631 - accuracy: 0.9041 - val_loss: 0.3027 - val_accuracy: 0.8539
# Epoch 13/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.2636 - accuracy: 0.9041 - val_loss: 0.3003 - val_accuracy: 0.8630
# Epoch 14/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.2638 - accuracy: 0.8982 - val_loss: 0.3203 - val_accuracy: 0.8447
# Epoch 15/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.2677 - accuracy: 0.8875 - val_loss: 0.3104 - val_accuracy: 0.8447
# Epoch 16/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2498 - accuracy: 0.9051 - val_loss: 0.3043 - val_accuracy: 0.8630
# Epoch 17/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2483 - accuracy: 0.9070 - val_loss: 0.3661 - val_accuracy: 0.8402
# Epoch 18/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.2430 - accuracy: 0.9129 - val_loss: 0.3761 - val_accuracy: 0.8630
# Epoch 19/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.2529 - accuracy: 0.9022 - val_loss: 0.3052 - val_accuracy: 0.8493
# Epoch 20/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2515 - accuracy: 0.8992 - val_loss: 0.3323 - val_accuracy: 0.8584
# Epoch 21/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2505 - accuracy: 0.8963 - val_loss: 0.3086 - val_accuracy: 0.8630
# Epoch 22/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.2685 - accuracy: 0.8992 - val_loss: 0.3049 - val_accuracy: 0.8447
# Epoch 23/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.2407 - accuracy: 0.9119 - val_loss: 0.2940 - val_accuracy: 0.8584
# Epoch 24/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2379 - accuracy: 0.9139 - val_loss: 0.3111 - val_accuracy: 0.8493
# Epoch 25/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2395 - accuracy: 0.9041 - val_loss: 0.3260 - val_accuracy: 0.8447
# Epoch 26/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2544 - accuracy: 0.9022 - val_loss: 0.3125 - val_accuracy: 0.8447
# Epoch 27/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2226 - accuracy: 0.9178 - val_loss: 0.3774 - val_accuracy: 0.8356
# Epoch 28/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.2313 - accuracy: 0.9178 - val_loss: 0.2887 - val_accuracy: 0.8676
# Epoch 29/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2259 - accuracy: 0.9041 - val_loss: 0.2858 - val_accuracy: 0.8630
# Epoch 30/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2220 - accuracy: 0.9129 - val_loss: 0.3153 - val_accuracy: 0.8493
# Epoch 31/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2294 - accuracy: 0.9051 - val_loss: 0.3232 - val_accuracy: 0.8402
# Epoch 32/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2285 - accuracy: 0.9110 - val_loss: 0.3688 - val_accuracy: 0.8630
# Epoch 33/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2679 - accuracy: 0.8982 - val_loss: 0.3132 - val_accuracy: 0.8813
# Epoch 34/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2463 - accuracy: 0.8924 - val_loss: 0.2852 - val_accuracy: 0.8630
# Epoch 35/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2426 - accuracy: 0.9041 - val_loss: 0.2736 - val_accuracy: 0.8676
# Epoch 36/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2191 - accuracy: 0.9149 - val_loss: 0.2817 - val_accuracy: 0.8721
# Epoch 37/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2108 - accuracy: 0.9188 - val_loss: 0.2967 - val_accuracy: 0.8539
# Epoch 38/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2178 - accuracy: 0.9129 - val_loss: 0.2987 - val_accuracy: 0.8721
# Epoch 39/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2243 - accuracy: 0.9168 - val_loss: 0.3041 - val_accuracy: 0.8402
# Epoch 40/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2259 - accuracy: 0.9100 - val_loss: 0.2704 - val_accuracy: 0.8721
# Epoch 41/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2066 - accuracy: 0.9217 - val_loss: 0.3158 - val_accuracy: 0.8447
# Epoch 42/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2146 - accuracy: 0.9178 - val_loss: 0.2855 - val_accuracy: 0.8584
# Epoch 43/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2240 - accuracy: 0.9070 - val_loss: 0.2868 - val_accuracy: 0.8539
# Epoch 44/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2168 - accuracy: 0.9207 - val_loss: 0.2924 - val_accuracy: 0.8676
# Epoch 45/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2073 - accuracy: 0.9168 - val_loss: 0.2936 - val_accuracy: 0.8767
# Epoch 46/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2286 - accuracy: 0.9110 - val_loss: 0.2804 - val_accuracy: 0.8676
# Epoch 47/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2129 - accuracy: 0.9159 - val_loss: 0.3201 - val_accuracy: 0.8584
# Epoch 48/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2109 - accuracy: 0.9129 - val_loss: 0.3147 - val_accuracy: 0.8447
# Epoch 49/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2008 - accuracy: 0.9227 - val_loss: 0.3107 - val_accuracy: 0.8721
# Epoch 50/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2290 - accuracy: 0.9188 - val_loss: 0.2667 - val_accuracy: 0.8721
# Epoch 51/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2241 - accuracy: 0.9119 - val_loss: 0.2945 - val_accuracy: 0.8584
# Epoch 52/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2049 - accuracy: 0.9217 - val_loss: 0.3139 - val_accuracy: 0.8447
# Epoch 53/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2147 - accuracy: 0.9110 - val_loss: 0.3365 - val_accuracy: 0.8402
# Epoch 54/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2021 - accuracy: 0.9247 - val_loss: 0.3079 - val_accuracy: 0.8676
# Epoch 55/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2089 - accuracy: 0.9168 - val_loss: 0.2950 - val_accuracy: 0.8721
# Epoch 56/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2284 - accuracy: 0.9041 - val_loss: 0.3157 - val_accuracy: 0.8767
# Epoch 57/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2037 - accuracy: 0.9139 - val_loss: 0.3017 - val_accuracy: 0.8447
# Epoch 58/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.1948 - accuracy: 0.9237 - val_loss: 0.2742 - val_accuracy: 0.8630
# Epoch 59/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2057 - accuracy: 0.9198 - val_loss: 0.2762 - val_accuracy: 0.8767
# Epoch 60/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2040 - accuracy: 0.9207 - val_loss: 0.3163 - val_accuracy: 0.8402
# Epoch 61/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2027 - accuracy: 0.9188 - val_loss: 0.3158 - val_accuracy: 0.8493
# Epoch 62/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.1966 - accuracy: 0.9315 - val_loss: 0.2973 - val_accuracy: 0.8630
# Epoch 63/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1969 - accuracy: 0.9227 - val_loss: 0.2887 - val_accuracy: 0.8721
# Epoch 64/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.2033 - accuracy: 0.9168 - val_loss: 0.2985 - val_accuracy: 0.8676
# Epoch 65/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2110 - accuracy: 0.9207 - val_loss: 0.3046 - val_accuracy: 0.8630
# Epoch 66/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2200 - accuracy: 0.9217 - val_loss: 0.2985 - val_accuracy: 0.8584
# Epoch 67/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2148 - accuracy: 0.9119 - val_loss: 0.3097 - val_accuracy: 0.8493
# Epoch 68/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.2117 - accuracy: 0.9159 - val_loss: 0.2755 - val_accuracy: 0.8721
# Epoch 69/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2036 - accuracy: 0.9178 - val_loss: 0.2897 - val_accuracy: 0.8721
# Epoch 70/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1966 - accuracy: 0.9266 - val_loss: 0.2777 - val_accuracy: 0.8584
# Epoch 71/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2069 - accuracy: 0.9198 - val_loss: 0.2995 - val_accuracy: 0.8630
# Epoch 72/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2000 - accuracy: 0.9178 - val_loss: 0.2675 - val_accuracy: 0.8721
# Epoch 73/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1888 - accuracy: 0.9247 - val_loss: 0.3025 - val_accuracy: 0.8676
# Epoch 74/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2008 - accuracy: 0.9207 - val_loss: 0.2749 - val_accuracy: 0.8630
# Epoch 75/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1963 - accuracy: 0.9198 - val_loss: 0.3159 - val_accuracy: 0.8767
# Epoch 76/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2027 - accuracy: 0.9188 - val_loss: 0.3406 - val_accuracy: 0.8356
# Epoch 77/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2244 - accuracy: 0.9178 - val_loss: 0.3004 - val_accuracy: 0.8539
# Epoch 78/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2005 - accuracy: 0.9227 - val_loss: 0.2611 - val_accuracy: 0.8767
# Epoch 79/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2108 - accuracy: 0.9227 - val_loss: 0.2848 - val_accuracy: 0.8676
# Epoch 80/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.2062 - accuracy: 0.9237 - val_loss: 0.3116 - val_accuracy: 0.8493
# Epoch 81/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1975 - accuracy: 0.9227 - val_loss: 0.2710 - val_accuracy: 0.8721
# Epoch 82/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1890 - accuracy: 0.9227 - val_loss: 0.3280 - val_accuracy: 0.8493
# Epoch 83/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1977 - accuracy: 0.9237 - val_loss: 0.2799 - val_accuracy: 0.8676
# Epoch 84/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1985 - accuracy: 0.9237 - val_loss: 0.2721 - val_accuracy: 0.8721
# Epoch 85/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1950 - accuracy: 0.9188 - val_loss: 0.2735 - val_accuracy: 0.8767
# Epoch 86/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2128 - accuracy: 0.9139 - val_loss: 0.2889 - val_accuracy: 0.8539
# Epoch 87/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1827 - accuracy: 0.9384 - val_loss: 0.2898 - val_accuracy: 0.8721
# Epoch 88/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1989 - accuracy: 0.9159 - val_loss: 0.2706 - val_accuracy: 0.8630
# Epoch 89/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1979 - accuracy: 0.9315 - val_loss: 0.3516 - val_accuracy: 0.8219
# Epoch 90/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1955 - accuracy: 0.9188 - val_loss: 0.3350 - val_accuracy: 0.8493
# Epoch 91/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1762 - accuracy: 0.9305 - val_loss: 0.2826 - val_accuracy: 0.8584
# Epoch 92/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1874 - accuracy: 0.9276 - val_loss: 0.2790 - val_accuracy: 0.8630
# Epoch 93/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.1796 - accuracy: 0.9325 - val_loss: 0.3110 - val_accuracy: 0.8767
# Epoch 94/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1995 - accuracy: 0.9305 - val_loss: 0.2842 - val_accuracy: 0.8721
# Epoch 95/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.2129 - accuracy: 0.9139 - val_loss: 0.2865 - val_accuracy: 0.8447
# Epoch 96/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1948 - accuracy: 0.9393 - val_loss: 0.2860 - val_accuracy: 0.8539
# Epoch 97/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1991 - accuracy: 0.9227 - val_loss: 0.2807 - val_accuracy: 0.8676
# Epoch 98/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1861 - accuracy: 0.9266 - val_loss: 0.2781 - val_accuracy: 0.8767
# Epoch 99/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1956 - accuracy: 0.9159 - val_loss: 0.2758 - val_accuracy: 0.8539
# Epoch 100/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.1997 - accuracy: 0.9159 - val_loss: 0.2894 - val_accuracy: 0.8721

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_3.history['accuracy'])
plt.plot(hist_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
